# %% [markdown]
# ### **<h3 id="info">Estudiante</h3>**
# ##### ***Nombre:*** Ian Tomas Felipe Fonseca Coronado.
# ##### ***ID:*** 00020555866.
# ##### ***Materia:*** Procesamiento de datos a gran escala.
# ##### ***Carrera:*** Ciencia de datos.
# ##### ***Semestre:*** Quinto.
# <hr>

# %% [markdown]
# <h2 id="func">Funciones</h2>

# %% [markdown]
# Una función es un bloque de código reutilizable que realiza las operaciones especificadas en la función. Le permiten dividir las tareas y reutilizar su código en diferentes programas.
#
# Hay dos tipos de funciones:
#
# - <b>Funciones predefinidas</b>
# - <b>Funciones definidas por el usuario</b>

# %% [markdown]
# <h3 id="content">¿Qué es una función?</h3>

# %% [markdown]
# Puede definir funciones para proporcionar la funcionalidad requerida. Aquí hay reglas simples para definir una función en Python:
# - Los bloques de funciones comienzan <code> def </code> seguidos por la función <code> name </code> y entre paréntesis <code> () </code>.
# - Hay parámetros de entrada o argumentos que deben colocarse entre estos paréntesis.
# - También puede definir parámetros dentro de estos paréntesis.
# - Hay un cuerpo dentro de cada función que comienza con dos puntos (<code>: </code>) y tiene sangría.
# - También puede colocar la documentación antes del cuerpo.
# - La instrucción <code> return </code> sale de una función y, opcionalmente, devuelve un valor.
#
# Un ejemplo de una función que se agrega al parámetro <code> a </code> imprime y devuelve la salida como <code> b </code>:

# %%
# Primer ejemplo de funcion:  Suma 1 en a y almacena en b

def add(a):
    b = a + 1
    print(a, "si sumas 1", b)
    return(b)

# %% [markdown]
# La siguiente figura ilustra la terminología:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%203/Images/FuncsDefinition.png" width="500" />

# %% [markdown]
# Podemos obtener ayuda sobre una función:

# %%
# Get a help on add function

help(add)
# Out:
# Help on function add in module __main__:
#
# add(a)

# %% [markdown]
# Podemos llamar a la función:

# %%
# Call the function add()

add(1)
# Out:
# 1 si sumas 1 2
# 2

# %% [markdown]
# Si llamamos a la función con una nueva entrada obtenemos un nuevo resultado:

# %%
# Call the function add()

add(2)
# Out:
# 2 si sumas 1 3
# 3

# %% [markdown]
# Podemos crear diferentes funciones. Por ejemplo, podemos crear una función que multiplique dos números. Los números estarán representados por las variables <code> a </code> y <code> b </code>:

# %%
# Define a function for multiple two numbers

def Mult(a, b):
    c = a * b
    return(c)

# %% [markdown]
# La misma función se puede utilizar para diferentes tipos de datos. Por ejemplo, podemos multiplicar dos números enteros:

# %%
# Use mult() multiply two integers

Mult(2, 3)
# Out:
# 6

# %% [markdown]
# Dos Floats:

# %%
# Use mult() multiply two floats

Mult(10.0, 3.14)
# Out:
# 31.400000000000002

# %% [markdown]
# Incluso podemos replicar una cadena multiplicándola por un número entero:

# %%
# Use mult() multiply two different type values together

Mult(2, "Michael Jackson ")
# Out:
# 'Michael Jackson Michael Jackson '

# %% [markdown]
# ### ***Analisis: ¿Qué es una función?***
# Las funciones son bloques de código que agrupan una o varias instrucciones con el fin de realizar una tarea específica y que pueden ser reutilizadas múltiples veces a lo largo de un programa en Python.
#
# Las funciones se definen utilizando el comando def, seguido del nombre de la función y unos paréntesis, dentro de los cuales se especifican los parámetros de entrada (si los hay). Al igual que en los condicionales y los bucles, se utilizan dos puntos para indicar el inicio del bloque de código que compone la función.
#
# Un comando muy útil para analizar y comprender el funcionamiento de una función es help, ya que permite ver información relevante como el nombre de la función, los parámetros que recibe y una descripción general de lo que devuelve o realiza.
# <hr>

# %% [markdown]
# <h3 id="var">Variables</h3>

# %% [markdown]
# La entrada a una función se llama parámetro formal.
#
# Una variable que se declara dentro de una función se llama variable local. El parámetro solo existe dentro de la función (es decir, el punto donde la función comienza y se detiene).
#
# Una variable que se declara fuera de la definición de una función es una variable global, y su valor es accesible y modificable en todo el programa. Discutiremos más sobre las variables globales al final de la práctica de laboratorio.

# %%
# Function Definition

def square(a):
    
    # Local variable b
    b = 1
    c = a * a + b
    print(a, "if you square + 1", c) 
    return(c)

# %% [markdown]
# Las etiquetas se muestran en la figura:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%203/Images/FuncsVar.png" width="500" />

# %% [markdown]
# Podemos llamar a la función con una entrada de <b> 3 </b>:

# %%
# Initializes Global variable  

x = 3
# Makes function call and return function a y
y = square(x)
y
# Out:
# 3 if you square + 1 10
# 10

# %% [markdown]
# Podemos llamar a la función con una entrada de <b> 2 </b> de una manera diferente:

# %%
# Directly enter a number as parameter

square(2)
# Out:
# 2 if you square + 1 5
# 5

# %% [markdown]
# Si no hay una instrucción <code> return </code>, la función devuelve <code> None </code>. Las siguientes dos funciones son equivalentes:

# %%
# Define functions, one with return value None and other without return value

def MJ():
    print('Michael Jackson')
    
def MJ1():
    print('Michael Jackson')
    return(None)

# %%
# See the output

MJ()
# Out:
# Michael Jackson

# %%
# See the output

MJ1()
# Out:
# Michael Jackson

# %% [markdown]
# La impresión de la función después de una llamada revela ** None ** es la declaración de retorno predeterminada:

# %%
# See what functions returns are

print(MJ())
print(MJ1())
# Out:
# Michael Jackson
# None
# Michael Jackson
# None

# %% [markdown]
# Cree una función <code> con </code> que concatene dos cadenas usando la operación de suma:

# %%
# Define the function for combining strings

def con(a, b):
    return(a + b)

# %%
# Test on the con() function

con("This ", "is")
# Out:
# 'This is'

# %% [markdown]
# ### ***Analisis: Variables***
# Las variables ya se han visto anteriormente y, en términos generales, son nombres que se asignan a datos de diferentes tipos, como enteros, decimales, cadenas de caracteres, etc., con el fin de representarlos sin necesidad de escribir el valor directamente cada vez que se necesite.
#
# Ahora bien, enfocándonos en las funciones, las variables se pueden dividir principalmente en dos tipos: variables locales y variables globales. Más adelante se hablará de manera más específica sobre las variables globales. Por el momento, es importante entender que las variables locales son aquellas que se definen dentro de una función, y por lo tanto solo existen y pueden ser utilizadas dentro de esa función. Fuera de ella, dichas variables no pueden ser accedidas.
#
# Otro aspecto importante relacionado con las variables aparece al momento de llamar una función. Cuando una función se define con parámetros, estos actúan como variables que reciben valores desde fuera de la función. Al llamar la función, se le pasan los valores que ocuparán esos parámetros y que serán utilizados dentro de la función.
#
# También existen casos en los que no es necesario definir parámetros de entrada, así como funciones que no devuelven ningún valor. En estos casos, la función simplemente ejecuta una serie de instrucciones y su valor de retorno es nulo, es decir, no retorna ningún dato explícitamente.
# <hr>

# %% [markdown]
# <h3 id="simple">Las funciones hacen las cosas más fáciles</h3>

# %% [markdown]
# Considere las dos líneas de código en <b> Block 1 </b> y <b> Block 2 </b>: el procedimiento para cada bloque es idéntico. Lo único que es diferente son los nombres y valores de las variables.

# %% [markdown]
# <h4>Block 1:</h4>

# %%
# a and b calculation block1

a1 = 4
b1 = 5
c1 = a1 + b1 + 2 * a1 * b1 - 1
if(c1 < 0):
    c1 = 0 
else:
    c1 = 5
c1
# Out:
# 5

# %% [markdown]
# <h4>Block 2:</h4>

# %%
# a and b calculation block2

a2 = 0
b2 = 0
c2 = a2 + b2 + 2 * a2 * b2 - 1
if(c2 < 0):
    c2 = 0 
else:
    c2 = 5
c2
# Out:
# 0

# %% [markdown]
# Podemos reemplazar las líneas de código con una función. Una función combina muchas instrucciones en una sola línea de código. Una vez que se define una función, se puede utilizar repetidamente. Puede invocar la misma función muchas veces en su programa. Puede guardar su función y usarla en otro programa o usar la función de otra persona. Las líneas de código en el código <b> Block 1 </b> y el código <b> Block 2 </b> se pueden reemplazar por la siguiente función:

# %%
# Make a Function for the calculation above

def Equation(a,b):
    c = a + b + 2 * a * b - 1
    if(c < 0):
        c = 0 
    else:
        c = 5
    return(c)

# %% [markdown]
# Esta función toma dos entradas, ayb, luego aplica varias operaciones para devolver c.
# Simplemente definimos la función, reemplazamos las instrucciones con la función e ingresamos los nuevos valores de <code> a1 </code>, <code> b1 </code> y <code> a2 </code>, <code> b2 </code> como entradas. Todo el proceso se demuestra en la figura:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%203/Images/FuncsPros.gif" width="850" />

# %% [markdown]
# El código ** Block 1 ** y ** Block 2 ** ahora se pueden reemplazar con el código ** Block 3 ** y el código ** Block 4 **.

# %% [markdown]
# <h4>Block 3:</h4>

# %%
a1 = 4
b1 = 5
c1 = Equation(a1, b1)
c1
# Out:
# 5

# %% [markdown]
# <h4>Block 4:</h4>

# %%
a2 = 0
b2 = 0
c2 = Equation(a2, b2)
c2
# Out:
# 0

# %% [markdown]
# ### ***Analisis: Las funciones hacen las cosas más fáciles***
# La forma más sencilla de entender cómo las funciones facilitan la programación es imaginar qué pasaría si no existieran. Como dice el dicho, uno valora más lo que tiene cuando no lo tiene.
#
# Sin funciones, cada vez que se necesitara realizar una misma operación, condición, ciclo o conjunto de instrucciones repetidamente, sería necesario escribir el mismo código una y otra vez. Esto no solo toma más tiempo, sino que también vuelve el código más largo, más difícil de mantener y más propenso a errores, ya que habría que cambiar manualmente variables o ajustar partes del código en cada repetición.
#
# Las funciones existen precisamente para resolver ese problema. Su objetivo es permitir que un bloque de código se escriba una sola vez, de manera fija o estática, y que luego pueda ser reutilizado en cualquier parte del programa simplemente llamando a la función.
#
# De esta forma, lo único que se necesita modificar son los valores de entrada (parámetros) cuando sea necesario, sin tener que reescribir todo el proceso. En pocas palabras, las funciones hacen que el código sea más corto, más claro, más ordenado y más fácil de mantener, ya que evitan la repetición innecesaria de instrucciones y permiten reutilizar el mismo código de forma sencilla.
# <hr>

# %% [markdown]
# <h2 id="pre">Funciones predefinidas</h2>

# %% [markdown]
# Hay muchas funciones predefinidas en Python, así que comencemos con las más simples.

# %% [markdown]
# La función <code> print () </code>:

# %%
# Build-in function print()

album_ratings = [10.0, 8.5, 9.5, 7.0, 7.0, 9.5, 9.0, 9.5] 
print(album_ratings)
# Out:
# [10.0, 8.5, 9.5, 7.0, 7.0, 9.5, 9.0, 9.5]

# %% [markdown]
# La función <code> sum () </code> agrega todos los elementos en una lista o tupla:

# %%
# Use sum() to add every element in a list or tuple together

sum(album_ratings)
# Out:
# 70.0

# %% [markdown]
# La función <code> len () </code> devuelve la longitud de una lista o tupla:

# %%
# Show the length of the list or tuple

len(album_ratings)
# Out:
# 8

# %%
str(album_ratings)
# Out:
# '[10.0, 8.5, 9.5, 7.0, 7.0, 9.5, 9.0, 9.5]'

# %%
max(album_ratings)
# Out:
# 10.0

# %%
min(album_ratings)
# Out:
# 7.0

# %%
round(album_ratings[0])
# Out:
# 10

# %% [markdown]
# ### ***Analisis: Funciones predefinidas***
# Como ya se ha visto, en Python es posible crear funciones propias con el fin de reutilizar un código específico las veces que sea necesario. Sin embargo, Python también cuenta con una gran cantidad de funciones predefinidas, las cuales ya vienen incorporadas en el lenguaje y están listas para usarse sin necesidad de definirlas.
#
# Un ejemplo claro es la función print, la cual permite imprimir en pantalla distintos tipos de datos, como números, listas, tuplas o cadenas de caracteres con mensajes personalizados.
# También está la función sum, que permite realizar sumas matemáticas, ya sea entre números individuales o entre los valores contenidos en estructuras como listas o tuplas numéricas. Cabe aclarar que sum no sirve para concatenar cadenas de caracteres, ya que su uso es exclusivamente matemático.
#
# Otra función muy utilizada es len, la cual permite obtener la longitud o cantidad de elementos de una estructura de datos, como una lista, una tupla o una cadena de caracteres.
# Además, existe la función str, que sirve para convertir cualquier valor que se pase como parámetro en una cadena de caracteres.
#
# También se pueden mencionar funciones como max y min, que permiten encontrar respectivamente el valor máximo y el valor mínimo dentro de un conjunto de datos numéricos.
# Por último, está la función round, cuya utilidad principal es redondear números, siendo especialmente útil cuando se trabaja con valores de tipo flotante (float).
# Eso por mencionar algunos.
# <hr>

# %% [markdown]
# <h2 id="if">Utilizando <code>if</code>/<code>else</code> y ciclos en Funciones</h2>

# %% [markdown]
# La función <code> return () </code> es particularmente útil si tiene alguna declaración IF en la función, cuando desea que su salida dependa de alguna condición:

# %%
# Function example

def type_of_album(artist, album, year_released):
    
    print(artist, album, year_released)
    if year_released > 1980:
        return "Modern"
    else:
        return "Oldie"
    
x = type_of_album("Michael Jackson", "Thriller", 1980)
print(x)
# Out:
# Michael Jackson Thriller 1980
# Oldie

# %% [markdown]
# Podemos usar un bucle en una función. Por ejemplo, podemos <code> imprimir </code> cada elemento en una lista:

# %%
# Print the list using for loop

def PrintList(the_list):
    for element in the_list:
        print(element)

# %%
# Implement the printlist function

PrintList(['1', 1, 'the man', "abc"])
# Out:
# 1
# 1
# the man
# abc

# %% [markdown]
# <h2 id="default">Establecer valores de argumento predeterminados en sus funciones personalizadas</h2>

# %% [markdown]
# Puede establecer un valor predeterminado para los argumentos en su función. Por ejemplo, en la función <code> isGoodRating () </code>, ¿qué pasaría si quisiéramos crear un umbral para lo que consideramos una buena calificación? Quizás de forma predeterminada, deberíamos tener una calificación predeterminada de 4:

# %%
# Example for setting param with default value

def isGoodRating(rating=4): 
    if(rating < 7):
        print("this album sucks it's rating is",rating)
        
    else:
        print("this album is good its rating is",rating)

# %%
# Test the value with default value and with input

isGoodRating()
isGoodRating(10)
# Out:
# this album sucks it's rating is 4
# this album is good its rating is 10

# %% [markdown]
# <h2 id="global">Variable globales</h2>

# %% [markdown]
# Hasta ahora, hemos estado creando variables dentro de funciones, pero no hemos discutido variables fuera de la función. Se denominan variables globales.
# <br>
# Intentemos ver qué devuelve <code> printer1 </code>:

# %%
# Example of global variable

artist = "Michael Jackson"
def printer1(artist):
    internal_var = artist
    print(artist, "is an artist")
    
printer1(artist)
# Out:
# Michael Jackson is an artist

# %% [markdown]
# Si imprimimos <code> internal_var </code> obtenemos un error.

# %% [markdown]
# <b> Tenemos un error de nombre: <code> nombre 'internal_var' no está definido </code>. ¿Por qué? </b>
#
# Es porque todas las variables que creamos en la función es una <b> variable local </b>, lo que significa que la asignación de la variable no persiste fuera de la función.
#
# Pero hay una forma de crear <b> variables globales </b> desde dentro de una función de la siguiente manera:

# %%
artist = "Michael Jackson"

def printer(artist):
    global internal_var 
    internal_var= "Whitney Houston"
    print(artist,"is an artist")

printer(artist) 
printer(internal_var)
# Out:
# Michael Jackson is an artist
# Whitney Houston is an artist

# %% [markdown]
# ### ***Analisis: Variable globales, Utilizando if/else y ciclos en Funciones y Establecer valores de argumento predeterminados en sus funciones personalizadas***
# En este punto se abordan tres conceptos relacionados entre sí: el uso de condicionales y ciclos dentro de funciones, los valores predeterminados en los argumentos de funciones, y las variables globales.
#
# Primero, respecto al uso de if-else y ciclos dentro de funciones, no hay mucho más que agregar a lo ya visto anteriormente. Las funciones permiten encapsular código que puede repetirse muchas veces, por lo que los condicionales y los bucles se ven directamente beneficiados. Gracias a las funciones, estos bloques de código pueden ejecutarse múltiples veces a lo largo del programa sin necesidad de reescribirlos constantemente, evitando códigos largos, repetitivos y poco eficientes.
#
# En cuanto a los valores predeterminados en los argumentos de funciones, este concepto se refiere a que, al momento de definir una función, es posible asignar un valor por defecto a uno o más parámetros dentro de los paréntesis. Por ejemplo, se puede definir un parámetro con un valor inicial, como asignarle el valor 4. Esto provoca que, si la función es llamada sin proporcionar un valor para ese parámetro, la función utilice automáticamente el valor predeterminado. De esta manera, la función sigue funcionando incluso cuando no se le pasan todos los argumentos, lo que la hace más flexible.
#
# Finalmente, están las variables globales. Las variables globales son lo opuesto a las variables locales. Mientras que las variables locales solo existen y funcionan dentro de una función específica, las variables globales existen en todo el programa y pueden ser utilizadas en cualquier parte del código. Más adelante se puede analizar con mayor detalle cómo estas variables globales interactúan con las funciones y cómo se relacionan con las variables locales definidas dentro de ellas.
# <hr>

# %% [markdown]
# <h2 id="scope">Ámbito de una variable</h2>

# %% [markdown]
# El alcance de una variable es la parte de ese programa donde esa variable es accesible. Las variables que se declaran fuera de todas las definiciones de funciones, como la variable <code> myFavouriteBand </code> en el código que se muestra aquí, son accesibles desde cualquier lugar dentro del programa. Como resultado, se dice que tales variables tienen alcance global y se conocen como variables globales.
#      <code> myFavouriteBand </code> es una variable global, por lo que es accesible desde la función <code> getBandRating </code>, y podemos usarla para determinar la clasificación de una banda. También podemos usarlo fuera de la función, como cuando lo pasamos a la función de impresión para mostrarlo:

# %%
# Example of global variable

myFavouriteBand = "AC/DC"

def getBandRating(bandname):
    if bandname == myFavouriteBand:
        return 10.0
    else:
        return 0.0

print("AC/DC's rating is:", getBandRating("AC/DC"))
print("Deep Purple's rating is:",getBandRating("Deep Purple"))
print("My favourite band is:", myFavouriteBand)
# Out:
# AC/DC's rating is: 10.0
# Deep Purple's rating is: 0.0
# My favourite band is: AC/DC

# %% [markdown]
# Eche un vistazo a esta versión modificada de nuestro código. Ahora la variable <code> myFavouriteBand </code> está definida dentro de la función <code> getBandRating </code>. Una variable que se define dentro de una función se dice que es una variable local de esa función. Eso significa que solo es accesible desde dentro de la función en la que está definido. Nuestra función <code> getBandRating </code> seguirá funcionando, porque <code> myFavouriteBand </code> todavía está definida dentro de la función. Sin embargo, ya no podemos imprimir <code> myFavouriteBand </code> fuera de nuestra función, porque es una variable local de nuestra función <code> getBandRating </code>; solo se define dentro de la función <code> getBandRating </code>:

# %%
# Example of local variable

def getBandRating(bandname):
    myFavouriteBand1 = "AC/DC"
    if bandname == myFavouriteBand1:
        return 10.0
    else:
        return 0.0

print("AC/DC's rating is: ", getBandRating("AC/DC"))
print("Deep Purple's rating is: ", getBandRating("Deep Purple"))
print("My favourite band is", myFavouriteBand1)
# Out:
# AC/DC's rating is:  10.0
# Deep Purple's rating is:  0.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 12
#      10 print("AC/DC's rating is: ", getBandRating("AC/DC"))
#      11 print("Deep Purple's rating is: ", getBandRating("Deep Purple"))
# ---> 12 print("My favourite band is", myFavouriteBand1)
#
# NameError: name 'myFavouriteBand1' is not defined

# %% [markdown]
# Finalmente, eche un vistazo a este ejemplo. Ahora tenemos dos definiciones de variable <code> myFavouriteBand </code>. El primero de ellos tiene un alcance global y el segundo es una variable local dentro de la función <code> getBandRating </code>. Dentro de la función <code> getBandRating </code>, la variable local tiene prioridad. ** Deep Purple ** recibirá una calificación de 10.0 cuando se pase a la función <code> getBandRating </code>. Sin embargo, fuera de la función <code> getBandRating </code>, la variable local <code> getBandRating </code> no está definida, por lo que la variable <code> myFavouriteBand </code> que imprimimos es la variable global, que tiene un valor de ** AC / DC **:

# %%
# Example of global variable and local variable with the same name

myFavouriteBand = "AC/DC"

def getBandRating(bandname):
    myFavouriteBand = "Deep Purple"
    if bandname == myFavouriteBand:
        return 10.0
    else:
        return 0.0

print("AC/DC's rating is:",getBandRating("AC/DC"))
print("Deep Purple's rating is: ",getBandRating("Deep Purple"))
print("My favourite band is:",myFavouriteBand)
# Out:
# AC/DC's rating is: 0.0
# Deep Purple's rating is:  10.0
# My favourite band is: AC/DC

# %% [markdown]
# ### ***Analisis: Ámbito de una variable***
# Como ya se mencionó anteriormente, las variables globales son aquellas que se definen fuera de las funciones y, por lo tanto, existen y funcionan a lo largo de todo el programa en Python. Es decir, una vez declaradas, pueden ser utilizadas en cualquier parte del código.
#
# Por otro lado, las variables locales son aquellas que se definen dentro de una función. Estas variables solo existen mientras la función se está ejecutando y únicamente pueden ser utilizadas dentro de dicha función. Una vez la función termina su ejecución, las variables locales dejan de existir.
#
# Ahora bien, surge una pregunta importante: ¿qué ocurre si existe una variable global y una variable local con el mismo nombre?
# En este caso, ambas variables pueden coexistir y tener valores diferentes. Por ejemplo, la variable global puede tener el valor 16, mientras que la variable local, definida dentro de una función, puede tener el valor 5.
#
# Cuando se ejecuta la función, la variable local tiene prioridad sobre la variable global. Esto significa que, aunque exista una variable global con el mismo nombre, Python utilizará el valor de la variable local dentro de la función y ignorará el valor de la variable global en ese contexto específico. Fuera de la función, la variable global seguirá conservando su valor original y funcionando con normalidad.
# <hr>

# %% [markdown]
# <h2>Cuestionario sobre funciones</h2>

# %% [markdown]
# Cree una función que divida la primera entrada por la segunda entrada:

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
def divicion(a,b):
    return a/b

# %% [markdown]
# Haz doble click __aquí__ para ver la solución..
#
# <!--
# def div(a, b):
#     return(a/b)
# -->

# %% [markdown]
# Utilice la función <code> con </code> para la siguiente pregunta.

# %%
# Usa la función con para la siguiente pregunta

def con(a, b):
    return(a + b)

# %% [markdown]
# ¿Se puede usar la función <code> con </code> que definimos antes para agregar números enteros o cadenas?

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
print(con(2, 2))
print(con('Aoi', ' Todo'))
# Out:
# 4
# Aoi Todo

# %% [markdown]
# Haz doble click __aquí__ para ver la solución.
#
# <!--
# yes, for example:
# con(2, 2)
#  -->

# %% [markdown]
# ¿Se puede usar la función <code> con </code> que definimos antes para concentrar una lista o tupla?

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
x= [1, 2, 3, 4]
y= ['1','2','3','4']
con(x, y)
# Out:
# [1, 2, 3, 4, '1', '2', '3', '4']

# %% [markdown]
# Haz doble click __aquí__ para ver la solución.
#
# <!--
# yes,for example:
# con(['a', 1], ['b', 1])
# -->

# %% [markdown]
# ### ***Conclusión***
# Se puede concluir que las funciones son una parte fundamental de la programación en Python, al mismo nivel que los condicionales y los ciclos, y que son uno de los principales motivos por los cuales Python es uno de los lenguajes de programación más usados y accesibles en la actualidad.
#
# Las funciones no son exclusivas de Python; existen en muchos otros lenguajes de programación. Sin embargo, la simplicidad y claridad con la que Python permite crearlas y utilizarlas hace que su implementación sea mucho más sencilla e intuitiva en comparación con otros lenguajes.
#
# Las funciones son esenciales para la creación de programas largos y organizados, ya que evitan el proceso extenuante de repetir una y otra vez el mismo código. Gracias a ellas, se pueden encapsular procesos complejos en bloques reutilizables, lo que simplifica enormemente el desarrollo del programa y reduce el esfuerzo de modificar variables o manejar múltiples casos repetitivos.
#
# En pocas palabras, las funciones representan un elemento clave que ha permitido que programar sea hoy en día mucho más fácil, ordenado y eficiente que en los inicios de la programación, convirtiéndose en una herramienta indispensable para cualquier desarrollador.
